# %% [markdown]
# # Project Notebook
#
#
# This notebook relates to the Fundamentals of Data Analysis project. The objective of the project is to investigate the variables and data points wihtin the the well know Iris Data set. The Iris dataset is accessed from the UCI machine learing repository and is commonly used in machine learning and data analysis examples/tutorials.
#
# The following information is taken from the iris.names file included in the data downloaded from the UCI machine learning repository. The attributes included within the file are sepal length in cm, sepal width in cm, petal length in cm, petal width in cm and class.
#
# The class varients are included in the dataset:
#     Iris Setosa
#     Iris Versicolour
#     Iris Virginica
#
# There are a total of 150 instances in the database, 50 for each of the three classes included in the data set.
#
# The following notebook explores the Iris dataset.

# %% [markdown]
# I will begin by importing the modules necessary to conduct analysis of the iris data set.

# %%
import numpy as np #import numpy module
import matplotlib.pyplot as plt #import matplotlib module
import pandas as pd #import pandas module
import seaborn as sns # import the seaborn module

# %%
#Next I will import the iris data set for use in the analysis. For this, I am importing the data from the iris data set stored in the local directory
data = pd.read_csv('iris.data', names= ["Sepal_Length_(cm)", "Sepal_Width_(cm)", "Petal_Length_(cm)", "Petal_Width_(cm)", "Class"]) #reading in the iris dataset and assigning names to each of the columns
df = data
# Out:
#    Sepal_Length_(cm)  Sepal_Width_(cm)  Petal_Length_(cm)  Petal_Width_(cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#          Class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# I will begin my analysis by generating an overview of the data set including summary statistics that give an overview of the data.

# %%
#First, I want to check that the data import process was suiccesfull. I extract the first five rows of the data set
df.head()
# Out:
#    Sepal_Length_(cm)  Sepal_Width_(cm)  Petal_Length_(cm)  Petal_Width_(cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#          Class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
#I then repeat the process for the last 5 records
df.tail()
# Out:
#      Sepal_Length_(cm)  Sepal_Width_(cm)  Petal_Length_(cm)  Petal_Width_(cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#               Class
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# The above confirms that the data was succesfully imported into the notebook. Instantly we can validate that 150 records have been imported and are included in the data fram df for analysis. I will now generate some summary information relating to the dataset.

# %%
df.info() #generate summary information relating to the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sepal_Length_(cm)  150 non-null    float64
#  1   Sepal_Width_(cm)   150 non-null    float64
#  2   Petal_Length_(cm)  150 non-null    float64
#  3   Petal_Width_(cm)   150 non-null    float64
#  4   Class              150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# The above analysis confirms that each variable has 150 records with sepal length, sepal width, petal length and petal width being numerical float values and the class value being an object or string value.

# %%
df.describe() #generate a description of the data set
# Out:
#        Sepal_Length_(cm)  Sepal_Width_(cm)  Petal_Length_(cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        Petal_Width_(cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# The above description further confirms the 150 records but also begins looking at some of the statistical characteristics of the data set. Included in the above analysis, we can see the average/mean, standard deviation, minimum and maximum of each of the variables within the data set.
#
# We will now generate histograms of the four numerical values included within the data set.

# %%
df.hist(bins=25, figsize=(12,6))
plt.suptitle("Histogram of the iris flowers dimensions")
plt.show()

# %% [markdown]
# Sepal length shows significant variation across the range of data with no clear groupings or concentration of data points. Sepal width on the other hand is heavily centred between 2.5 and 3.5 cm. Petal characteristics may be a more reliabe method of differentiating iris species with clear clusting to the left of the hystogram, indicating perhaps that one specieis is typically smaller than the other two cassifications of flowers. Next we will create box plots of the data, providing furhter insight to the data set. We expect the boxplots to confirm the summary statistics generated with the df.describe and df.info functions called above.

# %%
fig, ax = plt.subplots(2,2,sharey= False, figsize=(12,12))
sns.boxplot(x="Class", y="Sepal_Length_(cm)", data=df, ax = ax[0,0])
sns.boxplot(x="Class", y="Sepal_Width_(cm)", data=df, ax = ax[0,1])
sns.boxplot(x="Class", y="Petal_Length_(cm)", data=df, ax = ax[1,0])
sns.boxplot(x="Class", y="Petal_Width_(cm)", data=df, ax = ax[1,1])
fig.suptitle("Boxplot of Iris flower characteristics")
# Out:
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# Overall there are very few outliers in the data set across all of the variables.

# %%
sns.pairplot(df, hue="Class")
# Out:
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mcase\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# ***References***
#
# - https://archive.ics.uci.edu/dataset/53/iris
# - https://stackoverflow.com/questions/34091877/How-to-add-header-row-to-a-pandas-dataframe
# -
